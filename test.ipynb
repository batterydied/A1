# %% [markdown]
# # Prompting, Debugging, and Innovation for Code Generation with LLMs

# %%
from utils import generate_outputs, test, generate_revised_outputs, test_revised, generate_innovated_outputs

# %%
#generate_outputs()

# %%
test('deepseek', 'CoT', 0, 10)
# Out:
# Summary: 14/14 tests passed.
#
#
#
# Summary: 6/6 tests passed.
#
#
#
# Summary: 5/5 tests passed.
#
#
#
# Summary: 8/8 tests passed.
#
#
#
# Summary: 6/6 tests passed.
#
#
#
# Summary: 6/6 tests passed.
#
#
#
# Summary: 6/6 tests passed.
#
#
#
# Summary: 7/7 tests passed.
#
#
# humanEval_8
# Test 1 FAILED: input=([],), got (0, '*'), expected (0, 1)
# humanEval_8
# Test 2 FAILED: input=([1, 1, 1],), got (3, '*1*1*1'), expected (3, 1)
# humanEval_8
# Test 3 FAILED: input=([100, 0],), got (100, '*100*0'), expected (100, 0)
# humanEval_8
# Test 4 FAILED: input=([3, 5, 7],), got (15, '*3*5*7'), expected (15, 105)
# humanEval_8
# Test 5 FAILED: input=([10],), got (10, '*10'), expected (10, 10)
# humanEval_8
# Test 6 FAILED: input=([1, -1, 2, -2],), got (0, '*1*-1*2*-2'), expected (0, 4)
# humanEval_8
# Test 7 FAILED: input=([1, 2, 3, 4, 5],), got (15, '*1*2*3*4*5'), expected (15, 120)
#
# Summary: 0/7 tests passed.
#
#
#
# Summary: 10/10 tests passed.
#
#
# ...

# %%
test('deepseek', 'SCoT', 0, 10)
# Out:
# Summary: 14/14 tests passed.
#
#
#
# Summary: 6/6 tests passed.
#
#
#
# Summary: 5/5 tests passed.
#
#
#
# Summary: 8/8 tests passed.
#
#
#
# Summary: 6/6 tests passed.
#
#
#
# Summary: 6/6 tests passed.
#
#
#
# Summary: 6/6 tests passed.
#
#
#
# Summary: 7/7 tests passed.
#
#
#
# Summary: 7/7 tests passed.
#
#
#
# Summary: 10/10 tests passed.
#
#
# Total number of problems passed:  10

# %%
test('llama', 'CoT', 0, 10)
# Out:
# Summary: 14/14 tests passed.
#
#
#
# Summary: 6/6 tests passed.
#
#
#
# Summary: 5/5 tests passed.
#
#
#
# Summary: 8/8 tests passed.
#
#
#
# Summary: 6/6 tests passed.
#
#
#
# Summary: 6/6 tests passed.
#
#
#
# Summary: 6/6 tests passed.
#
#
#
# Summary: 7/7 tests passed.
#
#
#
# Summary: 7/7 tests passed.
#
#
#
# Summary: 10/10 tests passed.
#
#
# Total number of problems passed:  10

# %%
test('llama', 'SCoT', 0, 10)
# Out:
# Summary: 14/14 tests passed.
#
#
# humanEval_1
# Test 1 FAILED: input=('(()()) ((())) () ((())()())',), got [], expected ['(()())', '((()))', '()', '((())()())']
# humanEval_1
# Test 2 FAILED: input=('() (()) ((())) (((())))',), got [], expected ['()', '(())', '((()))', '(((())))']
# humanEval_1
# Test 3 FAILED: input=('(()(())((())))',), got [], expected ['(()(())((())))']
# humanEval_1
# Test 4 FAILED: input=('( ) (( )) (( )( ))',), got ['( )', '( )', '( )', '( )'], expected ['()', '(())', '(()())']
# humanEval_1
# Test 6 FAILED: input=('()',), got [], expected ['()']
#
# Summary: 1/6 tests passed.
#
#
#
# Summary: 5/5 tests passed.
#
#
#
# Summary: 8/8 tests passed.
#
#
#
# Summary: 6/6 tests passed.
#
#
#
# Summary: 6/6 tests passed.
#
#
#
# Summary: 6/6 tests passed.
#
#
#
# Summary: 7/7 tests passed.
#
#
#
# Summary: 7/7 tests passed.
#
#
#
# Summary: 10/10 tests passed.
#
#
# Total number of problems passed:  9

# %%
#generate_revised_outputs()

# %%
test_revised()
# Out:
# Summary: 7/7 tests passed.
# deepseek revised_p8 passed
#
#
#
# Summary: 6/6 tests passed.
# llama revised_p1 passed

# %%
#generate_innovated_outputs()

# %%
test('deepseek', 'innovated', 0, 10)
# Out:
# Summary: 14/14 tests passed.
#
#
#
# Summary: 6/6 tests passed.
#
#
#
# Summary: 5/5 tests passed.
#
#
#
# Summary: 8/8 tests passed.
#
#
#
# Summary: 6/6 tests passed.
#
#
#
# Summary: 6/6 tests passed.
#
#
#
# Summary: 6/6 tests passed.
#
#
#
# Summary: 7/7 tests passed.
#
#
#
# Summary: 7/7 tests passed.
#
#
#
# Summary: 10/10 tests passed.
#
#
# Total number of problems passed:  10

# %%
test('llama', 'innovated', 0, 10)
# Out:
# humanEval_0
# Test 12 FAILED: input=([1.0, inf], inf), got True, expected False
# humanEval_0
# Test 13 FAILED: input=([-inf, 1.0], inf), got True, expected False
#
# Summary: 12/14 tests passed.
#
#
#
# Summary: 6/6 tests passed.
#
#
#
# Summary: 5/5 tests passed.
#
#
#
# Summary: 8/8 tests passed.
#
#
#
# Summary: 6/6 tests passed.
#
#
# humanEval_5
# Test 2 FAILED: input=([5, 6, 3, 2], 8), got [5, 8, 3, 8, 8], expected [5, 8, 6, 8, 3, 8, 2]
# humanEval_5
# Test 3 FAILED: input=([2, 2, 2], 2), got [2, 2, 2, 2], expected [2, 2, 2, 2, 2]
# humanEval_5
# Test 5 FAILED: input=([1, 2], 0), got [1, 0], expected [1, 0, 2]
# humanEval_5
# Test 6 FAILED: input=([0, 1, 2, 3, 4], -1), got [0, -1, 2, -1, -1, 4, -1], expected [0, -1, 1, -1, 2, -1, 3, -1, 4]
#
# Summary: 2/6 tests passed.
#
#
# humanEval_6
# Test 1 FAILED: input=('(()()) ((())) () ((())()())',), got [3], expected [2, 3, 1, 3]
# humanEval_6
# Test 2 FAILED: input=('() (()) ((())) (((())))',), got [4], expected [1, 2, 3, 4]
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data = {
    "Strategy": ["CoT", "SCoT"],
    "HumanEval0": [1, 1],
    "HumanEval1": [1, 1],
    "HumanEval2": [1, 1],
    "HumanEval3": [1, 1],
    "HumanEval4": [1, 1],
    "HumanEval5": [1, 1],
    "HumanEval6": [1, 1],
    "HumanEval7": [1, 1],
    "HumanEval8": [0, 1],
    "HumanEval9": [1, 1],
}

df = pd.DataFrame(data).set_index("Strategy").T 

plt.figure(figsize=(6, 5))
sns.heatmap(df, annot=True, cmap="Blues", cbar=False, linewidths=0.5, linecolor="gray")

plt.title("Deepseek Pass@1")
plt.xlabel("Strategy")
plt.ylabel("HumanEval")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data = {
    "Strategy": ["CoT", "SCoT"],
    "HumanEval0": [1, 1],
    "HumanEval1": [1, 0],
    "HumanEval2": [1, 1],
    "HumanEval3": [1, 1],
    "HumanEval4": [1, 1],
    "HumanEval5": [1, 1],
    "HumanEval6": [1, 1],
    "HumanEval7": [1, 1],
    "HumanEval8": [1, 1],
    "HumanEval9": [1, 1],
}

df = pd.DataFrame(data).set_index("Strategy").T 

plt.figure(figsize=(6, 5))
sns.heatmap(df, annot=True, cmap="Blues", cbar=False, linewidths=0.5, linecolor="gray")

plt.title("Llama Pass@1")
plt.xlabel("Strategy")
plt.ylabel("HumanEval")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data = {
    "Strategy": ["Custom Prompt"],
    "HumanEval0": [1],
    "HumanEval1": [1],
    "HumanEval2": [1],
    "HumanEval3": [1],
    "HumanEval4": [1],
    "HumanEval5": [1],
    "HumanEval6": [1],
    "HumanEval7": [1],
    "HumanEval8": [1],
    "HumanEval9": [1],
}

df = pd.DataFrame(data).set_index("Strategy").T 

plt.figure(figsize=(6, 5))
sns.heatmap(df, annot=True, cmap="Blues", cbar=False, linewidths=0.5, linecolor="gray")

plt.title("Deepseek Pass@1")
plt.xlabel("Strategy")
plt.ylabel("HumanEval")

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data = {
    "Strategy": ["Custom Prompt"],
    "HumanEval0": [0],
    "HumanEval1": [1],
    "HumanEval2": [1],
    "HumanEval3": [1],
    "HumanEval4": [1],
    "HumanEval5": [0],
    "HumanEval6": [0],
    "HumanEval7": [1],
    "HumanEval8": [1],
    "HumanEval9": [1],
}

df = pd.DataFrame(data).set_index("Strategy").T 

plt.figure(figsize=(6, 5))
sns.heatmap(df, annot=True, cmap="Blues", cbar=False, linewidths=0.5, linecolor="gray")

plt.title("Llama Pass@1")
plt.xlabel("Strategy")
plt.ylabel("HumanEval")

plt.show()
